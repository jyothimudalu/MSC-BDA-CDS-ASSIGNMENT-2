# %%
pip install torch
# Out:
# ...
#
# ...
#      ---------------------------------------- 0.0/172.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/172.3 MB ? eta -:--:--
#      -------------------------------------- 0.0/172.3 MB 435.7 kB/s eta 0:06:36
#      ---------------------------------------- 0.2/172.3 MB 1.5 MB/s eta 0:01:55
#      ---------------------------------------- 0.5/172.3 MB 3.3 MB/s eta 0:00:52
#      ---------------------------------------- 0.9/172.3 MB 4.3 MB/s eta 0:00:40
#      ---------------------------------------- 1.2/172.3 MB 5.3 MB/s eta 0:00:33
#      ---------------------------------------- 1.6/172.3 MB 5.5 MB/s eta 0:00:32
#      ---------------------------------------- 2.0/172.3 MB 5.7 MB/s eta 0:00:30
#       --------------------------------------- 2.3/172.3 MB 5.9 MB/s eta 0:00:29
#       --------------------------------------- 2.5/172.3 MB 6.2 MB/s eta 0:00:28
#       --------------------------------------- 2.7/172.3 MB 5.6 MB/s eta 0:00:31
# ...

# %%
pip install numba
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting numba
#   Obtaining dependency information for numba from https://files.pythonhosted.org/packages/e8/1c/5d65ac922a4f9a6f90a10207b818e22e4d48a782af6574a6e7a50fae074d/numba-0.58.0-cp311-cp311-win_amd64.whl.metadata
#   Using cached numba-0.58.0-cp311-cp311-win_amd64.whl.metadata (2.8 kB)
# ...
#   Obtaining dependency information for llvmlite<0.42,>=0.41.0dev0 from https://files.pythonhosted.org/packages/14/3b/f9665a46486f70a7cbb6237308e49e18ed42e4763f4e92e92cd37ea67ead/llvmlite-0.41.0-cp311-cp311-win_amd64.whl.metadata
#   Using cached llvmlite-0.41.0-cp311-cp311-win_amd64.whl.metadata (5.0 kB)
# ...
#   Obtaining dependency information for numpy<1.26,>=1.21 from https://files.pythonhosted.org/packages/72/b2/02770e60c4e2f7e158d923ab0dea4e9f146a2dbf267fec6d8dc61d475689/numpy-1.25.2-cp311-cp311-win_amd64.whl.metadata
#   Using cached numpy-1.25.2-cp311-cp311-win_amd64.whl.metadata (5.7 kB)
# ...

# %%
pip install blaze
# Out:
# ...
#
# ...
#      ---------------------------------------- 0.0/472.5 kB ? eta -:--:--
#       --------------------------------------- 10.2/472.5 kB ? eta -:--:--
#      --- --------------------------------- 41.0/472.5 kB 653.6 kB/s eta 0:00:01
#      --------- ---------------------------- 122.9/472.5 kB 1.0 MB/s eta 0:00:01
#      --------------- ---------------------- 194.6/472.5 kB 1.7 MB/s eta 0:00:01
#      -------------------------------------  471.0/472.5 kB 2.5 MB/s eta 0:00:01
#      -------------------------------------- 472.5/472.5 kB 2.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Obtaining dependency information for flask>=0.10.1 from https://files.pythonhosted.org/packages/fd/56/26f0be8adc2b4257df20c1c4260ddd0aa396cf8e75d90ab2f7ff99bc34f9/flask-2.3.3-py3-none-any.whl.metadata
# ...

# %%
import numpy as np
import numba
import torch
import timeit

# Define matrix size
matrix_size = 1000

# NumPy benchmark
def numpy_benchmark():
    a = np.random.rand(matrix_size, matrix_size)
    b = np.random.rand(matrix_size, matrix_size)
    result = np.dot(a, b)

# Numba benchmark
@numba.jit
def numba_benchmark():
    a = np.random.rand(matrix_size, matrix_size)
    b = np.random.rand(matrix_size, matrix_size)
    result = np.dot(a, b)

# PyTorch benchmark
def pytorch_benchmark():
    a = torch.rand(matrix_size, matrix_size)
    b = torch.rand(matrix_size, matrix_size)
    result = torch.mm(a, b)

# Measure execution time
num_runs = 100  # Number of runs for each benchmark

numpy_time = timeit.timeit(numpy_benchmark, number=num_runs)
numba_time = timeit.timeit(numba_benchmark, number=num_runs)
pytorch_time = timeit.timeit(pytorch_benchmark, number=num_runs)

# Print results
print(f"NumPy Time: {numpy_time:.4f} seconds")
print(f"Numba Time: {numba_time:.4f} seconds")
print(f"PyTorch Time: {pytorch_time:.4f} seconds")
# Out:
# C:\Users\Jyothi\AppData\Local\Temp\ipykernel_7632\822681642.py:16: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit
# C:\Users\Jyothi\AppData\Local\Temp\ipykernel_7632\822681642.py:20: NumbaPendingDeprecationWarning: Code using Numba extension API maybe depending on 'old_style' error-capturing, which is deprecated and will be replaced by 'new_style' in a future release. See details at https://numba.readthedocs.io/en/latest/reference/deprecation.html#deprecation-of-old-style-numba-captured-errors
# Exception origin:
#   File "C:\Users\Jyothi\anaconda3\envs\jyothi\Lib\site-packages\numba\np\linalg.py", line 59, in ensure_blas
# ...

# %%
pip install cupy
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ...
#   Using cached cupy-12.2.0.tar.gz (2.0 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Obtaining dependency information for fastrlock>=0.5 from https://files.pythonhosted.org/packages/1d/6d/ccd8fce45a3a724a1682ebe4dc70f00a274e2a178852595298a1c43d70d4/fastrlock-0.8.2-cp311-cp311-win_amd64.whl.metadata
#   Using cached fastrlock-0.8.2-cp311-cp311-win_amd64.whl.metadata (9.6 kB)
# Using cached fastrlock-0.8.2-cp311-cp311-win_amd64.whl (29 kB)
# ...
#   Running setup.py clean for cupy
# Failed to build cupy
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [57 lines of output]
#   Clearing directory: C:\Users\Jyothi\AppData\Local\Temp\pip-install-p2qv5dc6\cupy_0938a2e13b704d07a318070f63df8b0b\cupy\.data
# ...

# %%
import timeit
import numpy as np
import numba
import torch

# Define the matrix size (adjust as needed)
matrix_size = (1000, 1000)

# Create random matrices for NumPy, CuPy, and PyTorch
numpy_matrix = np.random.rand(*matrix_size)
torch_matrix = torch.rand(*matrix_size)

# Define a NumPy function for the computation
def numpy_computation():
    result = numpy_matrix * numpy_matrix  # Element-wise multiplication
    return result


# Define a Numba function for the computation
@numba.jit
def numba_computation():
    result = numpy_matrix * numpy_matrix  # Element-wise multiplication
    return result

# Define a PyTorch function for the computation
def torch_computation():
    result = torch_matrix * torch_matrix  # Element-wise multiplication
    return result

# Benchmarking
numpy_time = timeit.timeit(numpy_computation, number=100)
numba_time = timeit.timeit(numba_computation, number=100)
torch_time = timeit.timeit(torch_computation, number=100)

# Print results
print(f"NumPy Time: {numpy_time} seconds")
print(f"Numba Time: {numba_time} seconds")
print(f"PyTorch Time: {torch_time} seconds")
# Out:
# C:\Users\Jyothi\AppData\Local\Temp\ipykernel_7632\440227100.py:20: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit
# NumPy Time: 0.43271290000120644 seconds
# Numba Time: 1.4768036999994365 seconds
# PyTorch Time: 0.2266908000001422 seconds
